# %%
import pyspark

# %%
spark  = pyspark.sql.SparkSession.builder.getOrCreate()
sc = spark.sparkContext

# %%
ratings = spark.read.json('data/ratings.json')

# %%
ratings.persist()
# Out:
# DataFrame[movie_id: bigint, rating: bigint, timestamp: double, user_id: bigint]

# %%
ratings.show(5)
# Out:
# +--------+------+------------+-------+
# |movie_id|rating|   timestamp|user_id|
# +--------+------+------------+-------+
# |     858|     4|9.56678732E8|   6040|
# |    2384|     4|9.56678754E8|   6040|
# |     593|     5|9.56678754E8|   6040|
# |    1961|     4|9.56678777E8|   6040|
# |    1419|     3|9.56678856E8|   6040|
# +--------+------+------------+-------+
# only showing top 5 rows

# %%
import pandas as pd 
movies = pd.read_csv('data/movies.dat', sep='::', engine='python', header=None)
len(movies)
# Out:
# 3883

# %%
users = pd.read_csv('data/users.dat', sep='::', engine='python', header=None)
users.head()
# Out:
#    0  1   2   3      4
# 0  1  F   1  10  48067
# 1  2  M  56  16  70072
# 2  3  M  25  15  55117
# 3  4  M  45   7  02460
# 4  5  M  25  20  55455

# %%
users = users.rename({0:'user_id', 
              1:'gender', 
              2:'min_age', 
              3:'occupation', 
              4:'zipcode'}, 
             axis=1)
users.min_age.value_counts()
# Out:
# 25    2096
# 35    1193
# 18    1103
# 45     550
# 50     496
# 56     380
# 1      222
# Name: min_age, dtype: int64

# %%
requests = spark.read.json('data/requests.json')

# %%
requests.persist()
# Out:
# DataFrame[movie_id: bigint, rating: double, timestamp: double, user_id: bigint]

# %%
requests.count()
# Out:
# 280260

# %%
ratings_df = ratings.toPandas()

# %%
ratings_df.head()
# Out:
#    movie_id  rating    timestamp  user_id
# 0       858       4  956678732.0     6040
# 1      2384       4  956678754.0     6040
# 2       593       5  956678754.0     6040
# 3      1961       4  956678777.0     6040
# 4      1419       3  956678856.0     6040

# %%
from pyspark.ml.recommendation import ALSModel, ALS

# %%
als = ALS(
    rank=11,
    userCol='user_id',
    itemCol='movie_id',
    ratingCol='rating'
)

# %%
als_model = als.fit(ratings)

# %%
preds = als_model.transform(ratings)

# %%
request_preds = als_model.transform(requests)

# %%
nan_df = request_preds.toPandas()

# %%
nan_df.head()
# Out:
#    movie_id  rating    timestamp  user_id  prediction
# 0       148     NaN  977959026.0       53         NaN
# 1       148     NaN  976559602.0     4169    3.068630
# 2       148     NaN  989024856.0     5333    2.389346
# 3       148     NaN  977005381.0     4387    2.161703
# 4       148     NaN  966907208.0     3539    2.734761

# %%
import numpy as np
nan_df = nan_df[nan_df['prediction'].isnull()]

# %%
nan_df.head()
# Out:
#     movie_id  rating     timestamp  user_id  prediction
# 0        148     NaN  9.779590e+08       53         NaN
# 6        148     NaN  9.768416e+08      216         NaN
# 7        148     NaN  9.761912e+08      482         NaN
# 9        148     NaN  1.026978e+09      424         NaN
# 14       463     NaN  9.782428e+08       26         NaN

# %%
len(nan_df)
# Out:
# 95628

# %%
meta_df = pd.read_csv('data/movies_metadata.csv')
# Out:
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
meta_df[meta_df.id.str.contains('-')==True]
#drop things that got shifted
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# 35587           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  2014-01-01       0
#
#       original_language                            original_title  overview  \
# 19730             104.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 29503              68.0      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 35587              82.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#          ...     release_date revenue runtime spoken_languages status  \
# 19730    ...                1     NaN     NaN              NaN    NaN
# 29503    ...               12     NaN     NaN              NaN    NaN
# 35587    ...               22     NaN     NaN              NaN    NaN
#
#        tagline  title video vote_average vote_count
# 19730      NaN    NaN   NaN          NaN        NaN
# 29503      NaN    NaN   NaN          NaN        NaN
# 35587      NaN    NaN   NaN          NaN        NaN
#
# [3 rows x 24 columns]

# %%
bad_ids = ['1997-08-20', '2012-09-29', '2014-01-01']

# %%
meta_df = meta_df[~meta_df['id'].isin(bad_ids)]
meta_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview    ...     release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...    ...       1995-10-30
# 1  When siblings Judy and Peter discover an encha...    ...       1995-12-15
# 2  A family wedding reignites the ancient feud be...    ...       1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...    ...       1995-12-22
# 4  Just when George Banks has recovered from his ...    ...       1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
meta_df['id'] = meta_df['id'].astype(int)

# %%
all_training_data_df = ratings_df.merge(meta_df, how='left', left_on='movie_id', right_on='id')

# %%
all_training_data_df = all_training_data_df.merge(users, how='left', left_on='user_id', right_on='user_id')

# %%
all_training_data_df.head().T
# Out:
#                                                                        0  \
# movie_id                                                             858
# rating                                                                 4
# timestamp                                                    9.56679e+08
# user_id                                                             6040
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                          21000000
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# homepage                                                             NaN
# id                                                                   858
# imdb_id                                                        tt0108160
# original_language                                                     en
# original_title                                      Sleepless in Seattle
# overview               A young boy who tries to set his dad up on a d...
# popularity                                                       10.2349
# poster_path                             /afkYP15OeUOD0tFEmj6VvejuOcz.jpg
# production_companies           [{'name': 'TriStar Pictures', 'id': 559}]
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  1993-06-24
# revenue                                                        2.278e+08
# runtime                                                              105
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                What if someone you never met, someone you nev...
# title                                               Sleepless in Seattle
# video                                                              False
# vote_average                                                         6.5
# vote_count                                                           630
# gender                                                                 M
# min_age                                                               25
# occupation                                                             6
# zipcode                                                            11106
#
#                                  1  \
# movie_id                      2384
# rating                           4
# timestamp              9.56679e+08
# user_id                       6040
# adult                          NaN
# belongs_to_collection          NaN
# budget                         NaN
# genres                         NaN
# homepage                       NaN
# id                             NaN
# imdb_id                        NaN
# original_language              NaN
# original_title                 NaN
# overview                       NaN
# popularity                     NaN
# poster_path                    NaN
# production_companies           NaN
# production_countries           NaN
# release_date                   NaN
# revenue                        NaN
# runtime                        NaN
# spoken_languages               NaN
# status                         NaN
# tagline                        NaN
# title                          NaN
# video                          NaN
# vote_average                   NaN
# vote_count                     NaN
# gender                           M
# min_age                         25
# occupation                       6
# zipcode                      11106
#
#                                                                        2  \
# movie_id                                                             593
# rating                                                                 5
# timestamp                                                    9.56679e+08
# user_id                                                             6040
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                 [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# homepage                                                             NaN
# id                                                                   593
# imdb_id                                                        tt0069293
# original_language                                                     ru
# original_title                                                   Солярис
# overview               Ground control has been receiving strange tran...
# popularity                                                       11.0598
# poster_path                             /nsGLKlwEOtqatz8yRdxOlAw5utr.jpg
# production_companies   [{'name': 'Mosfilm', 'id': 5120}, {'name': 'Cr...
# production_countries            [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# release_date                                                  1972-03-20
# revenue                                                                0
# runtime                                                              167
# spoken_languages                [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# status                                                          Released
# tagline                                                              NaN
# title                                                            Solaris
# video                                                              False
# vote_average                                                         7.7
# vote_count                                                           364
# gender                                                                 M
# min_age                                                               25
# occupation                                                             6
# zipcode                                                            11106
#
#                                                                        3  \
# movie_id                                                            1961
# rating                                                                 4
# timestamp                                                    9.56679e+08
# user_id                                                             6040
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                           1500000
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# homepage               http://www.dhentertainment.com/projects/1.my-n...
# id                                                                  1961
# imdb_id                                                        tt0489235
# original_language                                                     en
# original_title                                          My Name Is Bruce
# overview               B Movie Legend Bruce Campbell is mistaken for ...
# popularity                                                       8.70879
# poster_path                             /sUMogIAJ23VsCyoSk4Rx0i78JcI.jpg
# production_companies   [{'name': 'Dark Horse Entertainment', 'id': 55...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                  2007-10-01
# revenue                                                           173066
# runtime                                                               86
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                   Fearless! Unstoppable! Ready For His Close-Up!
# title                                                   My Name Is Bruce
# video                                                              False
# vote_average                                                         5.9
# vote_count                                                           107
# gender                                                                 M
# min_age                                                               25
# occupation                                                             6
# zipcode                                                            11106
#
#                                                                        4
# movie_id                                                            1419
# rating                                                                 3
# timestamp                                                    9.56679e+08
# user_id                                                             6040
# adult                                                              False
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# homepage                                http://www.vollidiot-derfilm.de/
# id                                                                  1419
# imdb_id                                                        tt0890888
# original_language                                                     de
# original_title                                                 Vollidiot
# overview               Based on Tommy Jaud's bestselling novel, this ...
# popularity                                                       1.99742
# poster_path                             /41EsLkSWhpCJ0hNGo5A2L0WsZ6C.jpg
# production_companies   [{'name': 'Senator Film Produktion', 'id': 191...
# production_countries           [{'iso_3166_1': 'DE', 'name': 'Germany'}]
# release_date                                                  2007-04-11
# revenue                                                                0
# runtime                                                              102
# spoken_languages                [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# status                                                          Released
# tagline                                                              NaN
# title                                                          Vollidiot
# video                                                              False
# vote_average                                                         4.3
# vote_count                                                            25
# gender                                                                 M
# min_age                                                               25
# occupation                                                             6
# zipcode                                                            11106

# %%
all_data_df = nan_df.merge(meta_df, how='left', left_on='movie_id', right_on='id')

# %%
all_data_df.head()
# Out:
#    movie_id  rating     timestamp  user_id  prediction  adult  \
# 0       148     NaN  9.779590e+08       53         NaN  False
# 1       148     NaN  9.768416e+08      216         NaN  False
# 2       148     NaN  9.761912e+08      482         NaN  False
# 3       148     NaN  1.026978e+09      424         NaN  False
# 4       463     NaN  9.782428e+08       26         NaN    NaN
#
#   belongs_to_collection   budget  \
# 0                   NaN  5000000
# 1                   NaN  5000000
# 2                   NaN  5000000
# 3                   NaN  5000000
# 4                   NaN      NaN
#
#                                               genres homepage    ...      \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN    ...
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN    ...
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN    ...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN    ...
# 4                                                NaN      NaN    ...
#
#    release_date revenue runtime  \
# 0    2005-12-15     0.0   112.0
# 1    2005-12-15     0.0   112.0
# 2    2005-12-15     0.0   112.0
# 3    2005-12-15     0.0   112.0
# 4           NaN     NaN     NaN
#
#                                     spoken_languages    status tagline  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released     NaN
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released     NaN
# 2  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released     NaN
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released     NaN
# 4                                                NaN       NaN     NaN
#
#                       title  video vote_average vote_count
# 0  The Secret Life of Words  False          6.8       52.0
# 1  The Secret Life of Words  False          6.8       52.0
# 2  The Secret Life of Words  False          6.8       52.0
# 3  The Secret Life of Words  False          6.8       52.0
# 4                       NaN    NaN          NaN        NaN
#
# [5 rows x 29 columns]

# %%
all_data_df = nan_df.merge(meta_df, how='left', left_on='movie_id', right_on='id')

# %%
all_data_df = all_data_df.merge(users, how='left', left_on='user_id', right_on='user_id')
all_data_df.head(2)
# Out:
#    movie_id  rating    timestamp  user_id  prediction  adult  \
# 0       148     NaN  977959026.0       53         NaN  False
# 1       148     NaN  976841639.0      216         NaN  False
#
#   belongs_to_collection   budget  \
# 0                   NaN  5000000
# 1                   NaN  5000000
#
#                                               genres homepage   ...    \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   ...
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   ...
#
#      status tagline                     title  video vote_average vote_count  \
# 0  Released     NaN  The Secret Life of Words  False          6.8       52.0
# 1  Released     NaN  The Secret Life of Words  False          6.8       52.0
#
#   gender min_age occupation zipcode
# 0      M      25          0   96931
# 1      M      45         13   52761
#
# [2 rows x 33 columns]

# %%
all_data_df.head(1)
# Out:
#    movie_id  rating    timestamp  user_id  prediction  adult  \
# 0       148     NaN  977959026.0       53         NaN  False
#
#   belongs_to_collection   budget  \
# 0                   NaN  5000000
#
#                                               genres homepage   ...    \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   ...
#
#      status tagline                     title  video vote_average vote_count  \
# 0  Released     NaN  The Secret Life of Words  False          6.8       52.0
#
#   gender min_age occupation zipcode
# 0      M      25          0   96931
#
# [1 rows x 33 columns]

# %%
X = all_data_df.filter(['zipcode','occupation','min_age','gender','vote_count', 'vote_average', 
                'runtime', 'revenue', 'release_date', 'popularity', 
               'budget', 'adult', 'user_id', 'movie_id'], axis=1)

# %%
y = all_data_df.filter(['prediction'], axis=1)

# %%
from keras.models import Sequential
from keras.layers import Dense 
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
gender_dict = {'M':0, 'F':1}

# %%
X['gender'] = X['gender'].replace(gender_dict)

# %%
adult_dict = {'True':True, 'False':False}

# %%
X['adult'] = X['adult'].replace(adult_dict)
type(X['adult'][0])
# Out:
# bool

# %%
X['budget'] = X['budget'].astype(float)

# %%
X.drop('zipcode', axis=1, inplace=True)

# %%
X['release_date'] = pd.DatetimeIndex(X['release_date']).astype(np.int64)

# %%
X['popularity'].astype(np.float64, copy=False)
type(X['popularity'][0])
# Out:
# float

# %%
#one-hot encode occupation
enc_cols = X['occupation'].values.reshape(-1, 1)
encoder = OneHotEncoder().fit(enc_cols)
encoder.get_feature_names(['occupation'])

ohe = pd.DataFrame(encoder.transform(enc_cols).toarray(),
                   columns=encoder.get_feature_names(['occupation']))

X = pd.concat([X.drop(['occupation'], axis=1), ohe], axis=1, )
# Out:
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:414: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
X.head().T
# Out:
#                                    0                    1  \
# min_age                           25                   45
# gender                             0                    0
# vote_count                        52                   52
# vote_average                     6.8                  6.8
# runtime                          112                  112
# revenue                            0                    0
# release_date     1134604800000000000  1134604800000000000
# popularity                   12.7756              12.7756
# budget                         5e+06                5e+06
# adult                          False                False
# user_id                           53                  216
# movie_id                         148                  148
# occupation_0.0                     1                    0
# occupation_1.0                     0                    0
# occupation_2.0                     0                    0
# occupation_3.0                     0                    0
# occupation_4.0                     0                    0
# occupation_5.0                     0                    0
# occupation_6.0                     0                    0
# occupation_7.0                     0                    0
# occupation_8.0                     0                    0
# occupation_9.0                     0                    0
# occupation_10.0                    0                    0
# occupation_11.0                    0                    0
# occupation_12.0                    0                    0
# occupation_13.0                    0                    1
# occupation_14.0                    0                    0
# occupation_15.0                    0                    0
# occupation_16.0                    0                    0
# occupation_17.0                    0                    0
# occupation_18.0                    0                    0
# occupation_19.0                    0                    0
# occupation_20.0                    0                    0
#
#                                    2                    3  \
# min_age                           25                   25
# gender                             0                    0
# vote_count                        52                   52
# vote_average                     6.8                  6.8
# runtime                          112                  112
# revenue                            0                    0
# release_date     1134604800000000000  1134604800000000000
# popularity                   12.7756              12.7756
# budget                         5e+06                5e+06
# adult                          False                False
# user_id                          482                  424
# movie_id                         148                  148
# occupation_0.0                     0                    0
# occupation_1.0                     0                    0
# occupation_2.0                     0                    0
# occupation_3.0                     0                    0
# occupation_4.0                     0                    0
# occupation_5.0                     0                    0
# occupation_6.0                     0                    0
# occupation_7.0                     0                    0
# occupation_8.0                     0                    0
# occupation_9.0                     0                    0
# occupation_10.0                    0                    0
# occupation_11.0                    0                    0
# occupation_12.0                    0                    0
# occupation_13.0                    0                    0
# occupation_14.0                    1                    0
# occupation_15.0                    0                    0
# occupation_16.0                    0                    0
# occupation_17.0                    0                    1
# occupation_18.0                    0                    0
# occupation_19.0                    0                    0
# occupation_20.0                    0                    0
#
#                                     4
# min_age                            25
# gender                              0
# vote_count                        NaN
# vote_average                      NaN
# runtime                           NaN
# revenue                           NaN
# release_date     -9223372036854775808
# popularity                        NaN
# budget                            NaN
# adult                             NaN
# user_id                            26
# movie_id                          463
# occupation_0.0                      0
# occupation_1.0                      0
# occupation_2.0                      0
# occupation_3.0                      0
# occupation_4.0                      0
# occupation_5.0                      0
# occupation_6.0                      0
# occupation_7.0                      1
# occupation_8.0                      0
# occupation_9.0                      0
# occupation_10.0                     0
# occupation_11.0                     0
# occupation_12.0                     0
# occupation_13.0                     0
# occupation_14.0                     0
# occupation_15.0                     0
# occupation_16.0                     0
# occupation_17.0                     0
# occupation_18.0                     0
# occupation_19.0                     0
# occupation_20.0                     0

# %%
X.drop(['occupation_0.0'], axis=1, inplace=True)

# %%
X.rename({'occupation_1.0':'academic_educator', 
          'occupation_2.0':'artist',
         'occupation_3.0':'clerical_admin',
         'occupation_4.0':'coll_grad_student',
         'occupation_5.0':'cust_service',
         'occupation_6.0':'doctor',
         'occupation_7.0':'exec',
         'occupation_8.0':'farmer',
         'occupation_9.0':'homemaker',
         'occupation_10.0':'young_student',
         'occupation_11.0':'lawyer',
         'occupation_12.0':'programmer',
         'occupation_13.0':'retired',
         'occupation_14.0':'sales_mkting',
          'occupation_15.0':'scientist',
         'occupation_16.0':'self_employed',
         'occupation_17.0':'tech_eng',
         'occupation_18.0':'tradesman',
          'occupation_19.0':'unemployed',
          'occupation_20.0':'writer',}, axis=1, inplace=True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95628 entries, 0 to 95627
# Data columns (total 32 columns):
# min_age              95628 non-null int64
# gender               95628 non-null int64
# vote_count           48000 non-null float64
# vote_average         48000 non-null float64
# runtime              48000 non-null float64
# revenue              48000 non-null float64
# release_date         95628 non-null int64
# popularity           48000 non-null object
# budget               48000 non-null float64
# adult                48000 non-null object
# user_id              95628 non-null int64
# movie_id             95628 non-null int64
# academic_educator    95628 non-null float64
# artist               95628 non-null float64
# clerical_admin       95628 non-null float64
# coll_grad_student    95628 non-null float64
# cust_service         95628 non-null float64
# doctor               95628 non-null float64
# exec                 95628 non-null float64
# farmer               95628 non-null float64
# homemaker            95628 non-null float64
# young_student        95628 non-null float64
# lawyer               95628 non-null float64
# programmer           95628 non-null float64
# retired              95628 non-null float64
# sales_mkting         95628 non-null float64
# scientist            95628 non-null float64
# self_employed        95628 non-null float64
# tech_eng             95628 non-null float64
# tradesman            95628 non-null float64
# unemployed           95628 non-null float64
# writer               95628 non-null float64
# dtypes: float64(25), int64(5), object(2)
# memory usage: 24.1+ MB

# %%
#X_3 will have more rows to train the model but we'll only take the predictions of the ones we still need
X_3 = X.drop(['vote_count', 'vote_average', 'runtime', 
                         'revenue', 'popularity', 'budget', 'adult'],axis=1)

# %%
X_2 = X.dropna()

# %%
X_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48000 entries, 0 to 95491
# Data columns (total 32 columns):
# min_age              48000 non-null int64
# gender               48000 non-null int64
# vote_count           48000 non-null float64
# vote_average         48000 non-null float64
# runtime              48000 non-null float64
# revenue              48000 non-null float64
# release_date         48000 non-null int64
# popularity           48000 non-null object
# budget               48000 non-null float64
# adult                48000 non-null object
# user_id              48000 non-null int64
# movie_id             48000 non-null int64
# academic_educator    48000 non-null float64
# artist               48000 non-null float64
# clerical_admin       48000 non-null float64
# coll_grad_student    48000 non-null float64
# cust_service         48000 non-null float64
# doctor               48000 non-null float64
# exec                 48000 non-null float64
# farmer               48000 non-null float64
# homemaker            48000 non-null float64
# young_student        48000 non-null float64
# lawyer               48000 non-null float64
# programmer           48000 non-null float64
# retired              48000 non-null float64
# sales_mkting         48000 non-null float64
# scientist            48000 non-null float64
# self_employed        48000 non-null float64
# tech_eng             48000 non-null float64
# tradesman            48000 non-null float64
# unemployed           48000 non-null float64
# writer               48000 non-null float64
# dtypes: float64(25), int64(5), object(2)
# memory usage: 12.1+ MB

# %%
X_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95628 entries, 0 to 95627
# Data columns (total 25 columns):
# min_age              95628 non-null int64
# gender               95628 non-null int64
# release_date         95628 non-null int64
# user_id              95628 non-null int64
# movie_id             95628 non-null int64
# academic_educator    95628 non-null float64
# artist               95628 non-null float64
# clerical_admin       95628 non-null float64
# coll_grad_student    95628 non-null float64
# cust_service         95628 non-null float64
# doctor               95628 non-null float64
# exec                 95628 non-null float64
# farmer               95628 non-null float64
# homemaker            95628 non-null float64
# young_student        95628 non-null float64
# lawyer               95628 non-null float64
# programmer           95628 non-null float64
# retired              95628 non-null float64
# sales_mkting         95628 non-null float64
# scientist            95628 non-null float64
# self_employed        95628 non-null float64
# tech_eng             95628 non-null float64
# tradesman            95628 non-null float64
# unemployed           95628 non-null float64
# writer               95628 non-null float64
# dtypes: float64(20), int64(5)
# memory usage: 19.0 MB

# %%
print(f'There are {95628-48000} predictions for our third model to make.')
# Out:
# There are 47628 predictions for our third model to make.

# %%
all_training_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 719949 entries, 0 to 719948
# Data columns (total 32 columns):
# movie_id                 719949 non-null int64
# rating                   719949 non-null int64
# timestamp                719949 non-null float64
# user_id                  719949 non-null int64
# adult                    361823 non-null object
# belongs_to_collection    88134 non-null object
# budget                   361823 non-null object
# genres                   361823 non-null object
# homepage                 90115 non-null object
# id                       361823 non-null float64
# imdb_id                  361823 non-null object
# original_language        361823 non-null object
# original_title           361823 non-null object
# overview                 360854 non-null object
# popularity               361823 non-null object
# poster_path              361823 non-null object
# production_companies     361823 non-null object
# production_countries     361823 non-null object
# release_date             361823 non-null object
# revenue                  361823 non-null float64
# runtime                  361823 non-null float64
# spoken_languages         361823 non-null object
# status                   361823 non-null object
# tagline                  261101 non-null object
# title                    361823 non-null object
# video                    361823 non-null object
# vote_average             361823 non-null float64
# vote_count               361823 non-null float64
# gender                   719949 non-null object
# min_age                  719949 non-null int64
# occupation               719949 non-null int64
# zipcode                  719949 non-null object
# dtypes: float64(6), int64(5), object(21)
# memory usage: 181.3+ MB

# %%
X_train = all_training_data_df.filter(['zipcode','occupation','min_age','gender','vote_count', 'vote_average', 
                'runtime', 'revenue', 'release_date', 'popularity', 
               'budget', 'adult', 'user_id', 'movie_id', 'rating'], axis=1)

# %%
X_train['gender'] = X_train['gender'].replace(gender_dict)

# %%
X_train['adult'] = X_train['adult'].replace(adult_dict)
type(X_train['adult'][0])
# Out:
# bool

# %%
X_train['budget'] = X_train['budget'].astype(float)

# %%
X_train.drop('zipcode', axis=1, inplace=True)

# %%
X_train['release_date'] = pd.DatetimeIndex(X_train['release_date']).astype(np.int64)

# %%
X_train['popularity'].astype(np.float64, copy=False)
type(X_train['popularity'][0])
# Out:
# float

# %%
#one-hot encode occupation
enc_cols = X_train['occupation'].values.reshape(-1, 1)
encoder = OneHotEncoder().fit(enc_cols)
encoder.get_feature_names(['occupation'])

ohe = pd.DataFrame(encoder.transform(enc_cols).toarray(),
                   columns=encoder.get_feature_names(['occupation']))

X_train = pd.concat([X_train.drop(['occupation'], axis=1), ohe], axis=1, )
# Out:
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/sklearn/preprocessing/_encoders.py:414: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
X_train.head().T
# Out:
#                                   0                     1                  2  \
# min_age                          25                    25                 25
# gender                            0                     0                  0
# vote_count                      630                   NaN                364
# vote_average                    6.5                   NaN                7.7
# runtime                         105                   NaN                167
# revenue                   2.278e+08                   NaN                  0
# release_date     740880000000000000  -9223372036854775808  69897600000000000
# popularity                  10.2349                   NaN            11.0598
# budget                      2.1e+07                   NaN                  0
# adult                         False                   NaN              False
# user_id                        6040                  6040               6040
# movie_id                        858                  2384                593
# rating                            4                     4                  5
# occupation_0.0                    0                     0                  0
# occupation_1.0                    0                     0                  0
# occupation_2.0                    0                     0                  0
# occupation_3.0                    0                     0                  0
# occupation_4.0                    0                     0                  0
# occupation_5.0                    0                     0                  0
# occupation_6.0                    1                     1                  1
# occupation_7.0                    0                     0                  0
# occupation_8.0                    0                     0                  0
# occupation_9.0                    0                     0                  0
# occupation_10.0                   0                     0                  0
# occupation_11.0                   0                     0                  0
# occupation_12.0                   0                     0                  0
# occupation_13.0                   0                     0                  0
# occupation_14.0                   0                     0                  0
# occupation_15.0                   0                     0                  0
# occupation_16.0                   0                     0                  0
# occupation_17.0                   0                     0                  0
# occupation_18.0                   0                     0                  0
# occupation_19.0                   0                     0                  0
# occupation_20.0                   0                     0                  0
#
#                                    3                    4
# min_age                           25                   25
# gender                             0                    0
# vote_count                       107                   25
# vote_average                     5.9                  4.3
# runtime                           86                  102
# revenue                       173066                    0
# release_date     1191196800000000000  1176249600000000000
# popularity                   8.70879              1.99742
# budget                       1.5e+06                    0
# adult                          False                False
# user_id                         6040                 6040
# movie_id                        1961                 1419
# rating                             4                    3
# occupation_0.0                     0                    0
# occupation_1.0                     0                    0
# occupation_2.0                     0                    0
# occupation_3.0                     0                    0
# occupation_4.0                     0                    0
# occupation_5.0                     0                    0
# occupation_6.0                     1                    1
# occupation_7.0                     0                    0
# occupation_8.0                     0                    0
# occupation_9.0                     0                    0
# occupation_10.0                    0                    0
# occupation_11.0                    0                    0
# occupation_12.0                    0                    0
# occupation_13.0                    0                    0
# occupation_14.0                    0                    0
# occupation_15.0                    0                    0
# occupation_16.0                    0                    0
# occupation_17.0                    0                    0
# occupation_18.0                    0                    0
# occupation_19.0                    0                    0
# occupation_20.0                    0                    0

# %%
X_train.drop(['occupation_0.0'], axis=1, inplace=True)

# %%
X_train.rename({'occupation_1.0':'academic_educator', 
          'occupation_2.0':'artist',
         'occupation_3.0':'clerical_admin',
         'occupation_4.0':'coll_grad_student',
         'occupation_5.0':'cust_service',
         'occupation_6.0':'doctor',
         'occupation_7.0':'exec',
         'occupation_8.0':'farmer',
         'occupation_9.0':'homemaker',
         'occupation_10.0':'young_student',
         'occupation_11.0':'lawyer',
         'occupation_12.0':'programmer',
         'occupation_13.0':'retired',
         'occupation_14.0':'sales_mkting',
          'occupation_15.0':'scientist',
         'occupation_16.0':'self_employed',
         'occupation_17.0':'tech_eng',
         'occupation_18.0':'tradesman',
          'occupation_19.0':'unemployed',
          'occupation_20.0':'writer',}, axis=1, inplace=True)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 719949 entries, 0 to 719948
# Data columns (total 33 columns):
# min_age              719949 non-null int64
# gender               719949 non-null int64
# vote_count           361823 non-null float64
# vote_average         361823 non-null float64
# runtime              361823 non-null float64
# revenue              361823 non-null float64
# release_date         719949 non-null int64
# popularity           361823 non-null object
# budget               361823 non-null float64
# adult                361823 non-null object
# user_id              719949 non-null int64
# movie_id             719949 non-null int64
# rating               719949 non-null int64
# academic_educator    719949 non-null float64
# artist               719949 non-null float64
# clerical_admin       719949 non-null float64
# coll_grad_student    719949 non-null float64
# cust_service         719949 non-null float64
# doctor               719949 non-null float64
# exec                 719949 non-null float64
# farmer               719949 non-null float64
# homemaker            719949 non-null float64
# young_student        719949 non-null float64
# lawyer               719949 non-null float64
# programmer           719949 non-null float64
# retired              719949 non-null float64
# sales_mkting         719949 non-null float64
# scientist            719949 non-null float64
# self_employed        719949 non-null float64
# tech_eng             719949 non-null float64
# tradesman            719949 non-null float64
# unemployed           719949 non-null float64
# writer               719949 non-null float64
# dtypes: float64(25), int64(6), object(2)
# memory usage: 186.8+ MB

# %%
#X_3 will have more rows to train the model but we'll only take the predictions of the ones we still need
X_3_train = X_train.drop(['vote_count', 'vote_average', 'runtime', 
                         'revenue', 'popularity', 'budget', 'adult', 'rating'],axis=1)
y_3_train = X_train.filter(['rating'], axis=1)

# %%
X_2_train = X_train.dropna()
y_2_train = X_2_train.filter(['rating'], axis=1)
X_2_train = X_2_train.drop(['rating'], axis=1)

# %%
X_2_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 361823 entries, 0 to 719948
# Data columns (total 32 columns):
# min_age              361823 non-null int64
# gender               361823 non-null int64
# vote_count           361823 non-null float64
# vote_average         361823 non-null float64
# runtime              361823 non-null float64
# revenue              361823 non-null float64
# release_date         361823 non-null int64
# popularity           361823 non-null object
# budget               361823 non-null float64
# adult                361823 non-null object
# user_id              361823 non-null int64
# movie_id             361823 non-null int64
# academic_educator    361823 non-null float64
# artist               361823 non-null float64
# clerical_admin       361823 non-null float64
# coll_grad_student    361823 non-null float64
# cust_service         361823 non-null float64
# doctor               361823 non-null float64
# exec                 361823 non-null float64
# farmer               361823 non-null float64
# homemaker            361823 non-null float64
# young_student        361823 non-null float64
# lawyer               361823 non-null float64
# programmer           361823 non-null float64
# retired              361823 non-null float64
# sales_mkting         361823 non-null float64
# scientist            361823 non-null float64
# self_employed        361823 non-null float64
# tech_eng             361823 non-null float64
# tradesman            361823 non-null float64
# unemployed           361823 non-null float64
# writer               361823 non-null float64
# dtypes: float64(25), int64(5), object(2)
# memory usage: 91.1+ MB

# %%
X_3_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 719949 entries, 0 to 719948
# Data columns (total 25 columns):
# min_age              719949 non-null int64
# gender               719949 non-null int64
# release_date         719949 non-null int64
# user_id              719949 non-null int64
# movie_id             719949 non-null int64
# academic_educator    719949 non-null float64
# artist               719949 non-null float64
# clerical_admin       719949 non-null float64
# coll_grad_student    719949 non-null float64
# cust_service         719949 non-null float64
# doctor               719949 non-null float64
# exec                 719949 non-null float64
# farmer               719949 non-null float64
# homemaker            719949 non-null float64
# young_student        719949 non-null float64
# lawyer               719949 non-null float64
# programmer           719949 non-null float64
# retired              719949 non-null float64
# sales_mkting         719949 non-null float64
# scientist            719949 non-null float64
# self_employed        719949 non-null float64
# tech_eng             719949 non-null float64
# tradesman            719949 non-null float64
# unemployed           719949 non-null float64
# writer               719949 non-null float64
# dtypes: float64(20), int64(5)
# memory usage: 142.8 MB

# %%
ss = StandardScaler()
X_2_scaled = ss.fit_transform(X_2)
X_2_train_scaled = ss.fit_transform(X_2_train)
X_3_train_scaled = ss.fit_transform(X_3_train)
X_3_scaled = ss.fit_transform(X_3)

# %%
model = Sequential()
inputs = X_2_scaled.shape[1]
hiddens = inputs
model.add(Dense(hiddens, input_dim=inputs, activation='relu'))
model.add(Dense(6, activation='softmax'))
adam=Adam()

# %%
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.utils import to_categorical
y_cat = to_categorical(y_2_train)

# %%
history = model.fit(X_2_train_scaled, y_cat, epochs=250)
# Out:
# Epoch 1/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4585 - acc: 0.3424
# Epoch 2/250
# 361823/361823 [==============================] - 8s 22us/step - loss: 1.4442 - acc: 0.3472
# Epoch 3/250
# 361823/361823 [==============================] - 8s 23us/step - loss: 1.4406 - acc: 0.3486
# Epoch 4/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4374 - acc: 0.3484
# Epoch 5/250
# 361823/361823 [==============================] - 7s 21us/step - loss: 1.4341 - acc: 0.3495
# Epoch 6/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4324 - acc: 0.3504
# Epoch 7/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4306 - acc: 0.3520
# Epoch 8/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4294 - acc: 0.3526
# Epoch 9/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4283 - acc: 0.3525
# Epoch 10/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4270 - acc: 0.3538
# Epoch 11/250
# 361823/361823 [==============================] - 8s 22us/step - loss: 1.4261 - acc: 0.3536
# Epoch 12/250
# 361823/361823 [==============================] - 8s 22us/step - loss: 1.4251 - acc: 0.3545
# Epoch 13/250
# 361823/361823 [==============================] - 7s 21us/step - loss: 1.4237 - acc: 0.3555
# Epoch 14/250
# 361823/361823 [==============================] - 7s 21us/step - loss: 1.4230 - acc: 0.3560
# Epoch 15/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4218 - acc: 0.3565
# Epoch 16/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4213 - acc: 0.3572
# Epoch 17/250
# 361823/361823 [==============================] - 7s 21us/step - loss: 1.4204 - acc: 0.3585
# Epoch 18/250
# 361823/361823 [==============================] - 7s 21us/step - loss: 1.4192 - acc: 0.3594
# Epoch 19/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4183 - acc: 0.3600
# Epoch 20/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4176 - acc: 0.3604
# Epoch 21/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4171 - acc: 0.3615
# Epoch 22/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4169 - acc: 0.3612
# Epoch 23/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4165 - acc: 0.3617
# Epoch 24/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4164 - acc: 0.3613
# Epoch 25/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4162 - acc: 0.3622
# Epoch 26/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4160 - acc: 0.3613
# Epoch 27/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4158 - acc: 0.3623
# Epoch 28/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4157 - acc: 0.3616
# Epoch 29/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4155 - acc: 0.3623
# Epoch 30/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4154 - acc: 0.3622
# Epoch 31/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4153 - acc: 0.3621
# Epoch 32/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4153 - acc: 0.3628
# Epoch 33/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4151 - acc: 0.3624
# Epoch 34/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4151 - acc: 0.3626
# Epoch 35/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4151 - acc: 0.3636
# Epoch 36/250
# 361823/361823 [==============================] - 8s 22us/step - loss: 1.4153 - acc: 0.3627
# Epoch 37/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4150 - acc: 0.3622
# Epoch 38/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4150 - acc: 0.3626
# Epoch 39/250
# 361823/361823 [==============================] - 8s 21us/step - loss: 1.4148 - acc: 0.3624
# Epoch 40/250
# 361823/361823 [==============================] - 8s 22us/step - loss: 1.4148 - acc: 0.3629
# Epoch 41/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4146 - acc: 0.3630
# Epoch 42/250
# 361823/361823 [==============================] - 7s 21us/step - loss: 1.4147 - acc: 0.3621
# Epoch 43/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4146 - acc: 0.3629
# Epoch 44/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4145 - acc: 0.3627
# Epoch 45/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4143 - acc: 0.3625
# Epoch 46/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4142 - acc: 0.3630
# Epoch 47/250
# 361823/361823 [==============================] - 7s 20us/step - loss: 1.4143 - acc: 0.3626
# Epoch 48/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4141 - acc: 0.3626
# Epoch 49/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4141 - acc: 0.3624
# Epoch 50/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4138 - acc: 0.3625
# Epoch 51/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4139 - acc: 0.3629
# Epoch 52/250
# 361823/361823 [==============================] - 7s 18us/step - loss: 1.4139 - acc: 0.3626
# Epoch 53/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4139 - acc: 0.3632
# Epoch 54/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4139 - acc: 0.3631
# Epoch 55/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4138 - acc: 0.3635
# Epoch 56/250
# 361823/361823 [==============================] - 7s 19us/step - loss: 1.4140 - acc: 0.3622
# Epoch 57/250
# 142112/361823 [==========>...................] - ETA: 4s - loss: 1.4142 - acc: 0.3626

# %%
requests_df = request_preds.toPandas()

# %%
for i, row in requests_df.iterrows():
    if str(row['prediction']) == 'nan':
        if row['user_id'] in X_2['user_id']:
            requests_df.loc[i, 'prediction'] = model.predict_classes(pd.DataFrame(X_2.loc[row['user_id'],:]).T)

# %%
model = Sequential()
inputs = X_3_scaled.shape[1]
hiddens = inputs
model.add(Dense(hiddens, input_dim=inputs, activation='relu'))
model.add(Dense(6, activation='softmax'))
adam=Adam()

# %%
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.utils import to_categorical
y_cat = to_categorical(y_3_train)

# %%
history = model.fit(X_3_train_scaled, y_cat, epochs=250)

# %%
for i, row in requests_df.iterrows():
    if str(row['prediction']) == 'nan':
        if row['user_id'] in X_3['user_id']:
            requests_df.loc[i, 'prediction'] = model.predict_classes(pd.DataFrame(X_3.loc[row['user_id'],:]).T)

# %%
requests_df
requests_df.to_json()

# %%
# with open('final_json.json', 'wb') as f:
#     json.dumps(requests_df.to_json())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
requests_df
# Out:
#         movie_id  rating     timestamp  user_id  prediction
# 0            148     NaN  9.779590e+08       53    5.000000
# 1            148     NaN  9.765596e+08     4169    3.068630
# 2            148     NaN  9.890249e+08     5333    2.389346
# 3            148     NaN  9.770054e+08     4387    2.161703
# 4            148     NaN  9.669072e+08     3539    2.734761
# 5            148     NaN  9.762665e+08      840    2.262279
# 6            148     NaN  9.768416e+08      216    5.000000
# 7            148     NaN  9.761912e+08      482    5.000000
# 8            148     NaN  1.029284e+09      752    3.038933
# 9            148     NaN  1.026978e+09      424    5.000000
# 10           148     NaN  9.741502e+08     2456    2.656042
# 11           148     NaN  9.701449e+08     3053    2.721665
# 12           463     NaN  9.805965e+08      970    2.699877
# 13           463     NaN  9.765609e+08     4169    2.419603
# 14           463     NaN  9.782428e+08       26    5.000000
# 15           463     NaN  9.763957e+08      319    5.000000
# 16           463     NaN  9.769077e+08      202    5.000000
# 17           463     NaN  9.757469e+08      721    3.262861
# 18           463     NaN  9.652831e+08     4252    2.131612
# 19           463     NaN  9.798267e+08      331    5.000000
# 20           463     NaN  9.761440e+08      524    5.000000
# 21           463     NaN  9.757491e+08     1962    1.946239
# 22           463     NaN  9.578645e+08     5831    2.821979
# 23           463     NaN  9.925224e+08      934    2.068399
# 24           471     NaN  1.038152e+09     1088    3.538878
# 25           471     NaN  9.762757e+08      392    5.000000
# 26           471     NaN  9.762509e+08      516    5.000000
# 27           471     NaN  1.011688e+09     1265    5.000000
# 28           471     NaN  1.017903e+09     4186    2.818800
# 29           471     NaN  9.759061e+08      588    5.000000
# ...          ...     ...           ...      ...         ...
# 280230      3910     NaN  1.027730e+09     5689    3.241750
# 280231      3910     NaN  9.948989e+08     1912    2.801931
# 280232      3910     NaN  1.005606e+09     2878    3.469798
# 280233      3910     NaN  9.762711e+08      390    5.000000
# 280234      3910     NaN  9.768707e+08      214    5.000000
# 280235      3910     NaN  1.010307e+09     1587    3.711818
# 280236      3910     NaN  9.778495e+08     2868    3.438710
# 280237      3910     NaN  9.771168e+08      195    5.000000
# 280238      3910     NaN  9.914063e+08     4815    4.105168
# 280239      3910     NaN  9.908778e+08     1203    3.942266
# 280240      3910     NaN  9.757670e+08      622    5.000000
# 280241      3910     NaN  9.920199e+08      151    5.000000
# 280242      3910     NaN  1.002918e+09     1579    3.464492
# 280243      3910     NaN  9.995389e+08     4834    3.168428
# 280244      3910     NaN  9.747634e+08     1285    3.907029
# 280245      3910     NaN  1.025210e+09      454    5.000000
# 280246      3910     NaN  9.885039e+08     1086    3.461808
# 280247      3910     NaN  9.774016e+08      131    5.000000
# 280248      3910     NaN  9.882904e+08      149    5.000000
# 280249      3910     NaN  9.855175e+08     4771    3.809830
# 280250      3910     NaN  1.043751e+09     5878    3.764273
# 280251      3910     NaN  9.944294e+08     6016    3.451468
# 280252      3910     NaN  9.765432e+08      281    5.000000
# 280253      3910     NaN  1.001689e+09     3503    4.193230
# 280254      3910     NaN  9.747281e+08     1445    3.638529
# 280255      3910     NaN  1.016788e+09     3371    3.767480
# 280256      3910     NaN  9.914236e+08     1851    3.132400
# 280257      3910     NaN  1.041582e+09     5198    3.552564
# 280258      3910     NaN  9.888308e+08     1584    3.495874
# 280259      3910     NaN  9.885431e+08     1246    3.391403
#
# [280260 rows x 5 columns]

# %%
requests_df.to_json('final_json.json')

# %%
requests_df = request_preds.toPandas()

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(multi_class='multinomial', solver='lbfgs')
lr.fit(X_2_train, y_2_train)
# Out:
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='multinomial', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
for i, row in requests_df.iterrows():
    if str(row['prediction']) == 'nan':
        if row['user_id'] in X_2['user_id']:
            requests_df.loc[i, 'prediction'] = lr.predict(pd.DataFrame(X_2.loc[row['user_id'],:]).T)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(multi_class='multinomial', solver='lbfgs')
lr.fit(X_3_train, y_3_train)
# Out:
# /anaconda3/envs/learn-env/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='multinomial', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
for i, row in requests_df.iterrows():
    if str(row['prediction']) == 'nan':
        if row['user_id'] in X_3['user_id']:
            requests_df.loc[i, 'prediction'] = lr.predict(pd.DataFrame(X_3.loc[row['user_id'],:]).T)

# %%
requests_df.to_json('final_json_logistic.json')

# %%
requests_df
# Out:
#         movie_id  rating     timestamp  user_id  prediction
# 0            148     NaN  9.779590e+08       53    4.000000
# 1            148     NaN  9.765596e+08     4169    3.068630
# 2            148     NaN  9.890249e+08     5333    2.389346
# 3            148     NaN  9.770054e+08     4387    2.161703
# 4            148     NaN  9.669072e+08     3539    2.734761
# 5            148     NaN  9.762665e+08      840    2.262279
# 6            148     NaN  9.768416e+08      216    1.000000
# 7            148     NaN  9.761912e+08      482    4.000000
# 8            148     NaN  1.029284e+09      752    3.038933
# 9            148     NaN  1.026978e+09      424    1.000000
# 10           148     NaN  9.741502e+08     2456    2.656042
# 11           148     NaN  9.701449e+08     3053    2.721665
# 12           463     NaN  9.805965e+08      970    2.699877
# 13           463     NaN  9.765609e+08     4169    2.419603
# 14           463     NaN  9.782428e+08       26    4.000000
# 15           463     NaN  9.763957e+08      319    1.000000
# 16           463     NaN  9.769077e+08      202    1.000000
# 17           463     NaN  9.757469e+08      721    3.262861
# 18           463     NaN  9.652831e+08     4252    2.131612
# 19           463     NaN  9.798267e+08      331    1.000000
# 20           463     NaN  9.761440e+08      524    4.000000
# 21           463     NaN  9.757491e+08     1962    1.946239
# 22           463     NaN  9.578645e+08     5831    2.821979
# 23           463     NaN  9.925224e+08      934    2.068399
# 24           471     NaN  1.038152e+09     1088    3.538878
# 25           471     NaN  9.762757e+08      392    1.000000
# 26           471     NaN  9.762509e+08      516    4.000000
# 27           471     NaN  1.011688e+09     1265    4.000000
# 28           471     NaN  1.017903e+09     4186    2.818800
# 29           471     NaN  9.759061e+08      588    4.000000
# ...          ...     ...           ...      ...         ...
# 280230      3910     NaN  1.027730e+09     5689    3.241750
# 280231      3910     NaN  9.948989e+08     1912    2.801931
# 280232      3910     NaN  1.005606e+09     2878    3.469798
# 280233      3910     NaN  9.762711e+08      390    1.000000
# 280234      3910     NaN  9.768707e+08      214    1.000000
# 280235      3910     NaN  1.010307e+09     1587    3.711818
# 280236      3910     NaN  9.778495e+08     2868    3.438710
# 280237      3910     NaN  9.771168e+08      195    1.000000
# 280238      3910     NaN  9.914063e+08     4815    4.105168
# 280239      3910     NaN  9.908778e+08     1203    3.942266
# 280240      3910     NaN  9.757670e+08      622    4.000000
# 280241      3910     NaN  9.920199e+08      151    4.000000
# 280242      3910     NaN  1.002918e+09     1579    3.464492
# 280243      3910     NaN  9.995389e+08     4834    3.168428
# 280244      3910     NaN  9.747634e+08     1285    3.907029
# 280245      3910     NaN  1.025210e+09      454    4.000000
# 280246      3910     NaN  9.885039e+08     1086    3.461808
# 280247      3910     NaN  9.774016e+08      131    4.000000
# 280248      3910     NaN  9.882904e+08      149    4.000000
# 280249      3910     NaN  9.855175e+08     4771    3.809830
# 280250      3910     NaN  1.043751e+09     5878    3.764273
# 280251      3910     NaN  9.944294e+08     6016    3.451468
# 280252      3910     NaN  9.765432e+08      281    1.000000
# 280253      3910     NaN  1.001689e+09     3503    4.193230
# 280254      3910     NaN  9.747281e+08     1445    3.638529
# 280255      3910     NaN  1.016788e+09     3371    3.767480
# 280256      3910     NaN  9.914236e+08     1851    3.132400
# 280257      3910     NaN  1.041582e+09     5198    3.552564
# 280258      3910     NaN  9.888308e+08     1584    3.495874
# 280259      3910     NaN  9.885431e+08     1246    3.391403
#
# [280260 rows x 5 columns]

# %%
movies_avg = ratings_df.groupby('movie_id').mean()

# %%
users_avg = ratings_df.groupby('user_id').mean()
users_avg.head()

# %%
request_df.head()

# %%
for i, row in request_df.iterrows():
    if str(row['prediction']) == 'nan':
        for user in users_avg.iterrows():
            if user.index == row['user_id']:
                for movie in movies_avg:
                    if movie['movie_id'] == row['movie_id']:
                        request_df.loc[i, 'prediction'] = (user['rating'] * movie['rating'])/2

# %%
request_df.to_json('final_final_json.json')

# %%
request_df
